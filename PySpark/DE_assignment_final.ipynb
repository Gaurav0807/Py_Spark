# %% [markdown]
# # Important Note
# #### The dataset and jupyter notebook must be in the same folder.
# #### The questions are divided into basic and moderate pandas question along with sql questions in last( More weightage is assigned to moderate questions)
# #### You will be judge on the basis of both correct answer as well as code quality
# #### Type the code in the empty cell provided below each question
# #### In case the question is not clear , Make your own assumptions and proceed with the solutions.

# %% [markdown]
# # Basic Questions

# %% [markdown]
# ## Import pandas library

# %%
import pandas as pd

# %% [markdown]
# ## Reading Titanic dataset as a dataframe  that has been provided to you

# %%
df1=pd.read_csv('titanic.csv')

# %% [markdown]
# ## Display/print the first 5 and last 5 rows of the original dataset

# %%
#df1.head()
#df1.tail()
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ##  Display/print the data type for each column in original dataset

# %%
print(df1.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ##  Find the total number of rows and columns in above dataset

# %%
df1.shape
# Out:
# (891, 12)

# %% [markdown]
# ##  List out all the columns for the original data set

# %%
print(df1.columns.values)
# Out:
# ['PassengerId' 'Survived' 'Pclass' 'Name' 'Sex' 'Age' 'SibSp' 'Parch'
#  'Ticket' 'Fare' 'Cabin' 'Embarked']

# %% [markdown]
#  ## Create a new dataframe containing only personnel info of Passenger(PassengerId, Name, Age, Sex)

# %%
df3=pd.DataFrame({
    'PassengerID':df1['PassengerId'],
    'Name':df1['Name'],
    'Age':df1['Age'],
    'sex':df1['Sex']
})
df3
# Out:
#      PassengerID                                               Name   Age  \
# 0              1                            Braund, Mr. Owen Harris  22.0
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2              3                             Heikkinen, Miss. Laina  26.0
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4              5                           Allen, Mr. William Henry  35.0
# ..           ...                                                ...   ...
# 886          887                              Montvila, Rev. Juozas  27.0
# 887          888                       Graham, Miss. Margaret Edith  19.0
# 888          889           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889          890                              Behr, Mr. Karl Howell  26.0
# 890          891                                Dooley, Mr. Patrick  32.0
#
#         sex
# 0      male
# 1    female
# 2    female
# 3    female
# ...

# %% [markdown]
#  ## Dropping duplicates from the original dataset(if any)

# %%
df1.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ##  Create an new dataframe by dropping all records that have atleast one null/Nan values from the original dataset

# %%
df4=df1.dropna()
df5=pd.DataFrame(df4)
df5
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Create a new dataframe after dropping columns Ticket and Cabin from the original dataset

# %%
df6=df1.drop(['Ticket','Cabin'],axis=1)
df6
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Sort the original dataframe on the basis of Fare in descending order and store it into a new dataframe

# %%
df7=df1.sort_values(["Fare"],ascending=False)
df8=pd.DataFrame(df7)
df8
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %% [markdown]
# ## Create a new dataframe that contains only the passengers that survived

# %%
df9=df1[df1['Survived']>0]
df9
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Moderate Questions

# %% [markdown]
# ## Create a new dataframe(df_survived) which follow all the following condition at the same time from the original dataset
# #### 1. All passengers should be male
# #### 2. The age of each passenger should be greater than 40 but less than 50
# #### 3. Passenger should not belong to 3rd PClass( Pclass not equal to 3)

# %%
# 'Sex': df1['Sex']=='male',
#     'Age':df1[(df1['Age']>40) and (df1['Age']<50)],
#     'PClass'df1['Pclass']!=3
    
df10 = df1[(df1['Sex']=='male') & (df1['Pclass']!=3) & (df1['Age']>40) & (df1['Age']<50)]
df_survived=pd.DataFrame(df10)
df_survived
# Out:
#      PassengerId  Survived  Pclass  \
# 35            36         0       1
# 62            63         0       1
# 92            93         0       1
# 110          111         0       1
# 149          150         0       2
# 187          188         1       1
# 217          218         0       2
# 236          237         0       2
# 245          246         0       1
# 288          289         1       2
# 314          315         0       2
# 331          332         0       1
# 339          340         0       1
# 397          398         0       2
# 453          454         1       1
# 460          461         1       1
# 462          463         0       1
# 463          464         0       2
# 515          516         0       1
# 536          537         0       1
# 586          587         0       2
# 599          600         1       1
# 621          622         1       1
# 645          646         1       1
# 662          663         0       1
# ...

# %% [markdown]
# ## Perform the following preprocess steps on the above  df_survived dataframe
# #### 1. Add 2 new columns first_name and second_name by splitting the Name column on comma(,)
# #### 2. Remove the prefixes from the second name( ex Mr. , Dr. etc)
# #### 3. Trim/Strip all the white spaces in above 2 columns( no space before and after the string in each cell)
# #### Your output should look like the below value in last 2 columns
# |Name|first_name|second_name|
# |---|---|---|
# |Daly, Mr. Peter Denis|Daly|Peter Denis|

# %%
split_data1=df_survived["Name"].str.split(",")
data1=split_data1.to_list()
df_survived["first_name"]=data1[0][0]
df_survived["second_name"]=data1[0][1]
df_survived["second_name"]=df_survived["second_name"].replace(['Mr. ','Dr. '],'', regex=True)
df_survived
# Out:
#      PassengerId  Survived  Pclass  \
# 35            36         0       1
# 62            63         0       1
# 92            93         0       1
# 110          111         0       1
# 149          150         0       2
# 187          188         1       1
# 217          218         0       2
# 236          237         0       2
# 245          246         0       1
# 288          289         1       2
# 314          315         0       2
# 331          332         0       1
# 339          340         0       1
# 397          398         0       2
# 453          454         1       1
# 460          461         1       1
# 462          463         0       1
# 463          464         0       2
# 515          516         0       1
# 536          537         0       1
# 586          587         0       2
# 599          600         1       1
# 621          622         1       1
# 645          646         1       1
# 662          663         0       1
# ...

# %% [markdown]
# ## Perform the following additional preprocess steps on the above df_survived dataframe
# #### 1. Add a new column economy_group which contain values "Rich" or "Not Rich" depend on whether the Pclass is 1 or not respectively
# #### 2. Add a new column age_group which contain values  "old" if age is more than 50,  "child" if age is less than 15 otherwise  "young"
# #### 3. Add a new column name_length which contain the string length for Name column

# %%
def new_column(row):
    if row['Age']>50:
        return "old"
    elif row['Age']<15:
        return "child"
    else:
        return "young"
df_survived['Economy_Group']=df_survived['Pclass'].apply(lambda x: 'Rich' if x==1 else 'Not Rich')
df_survived['Age_Group']=df_survived.apply(new_column,axis=1)
df_survived['Name_length']=df_survived['Name'].apply(lambda x: len(x))

df_survived
# Out:
#      PassengerId  Survived  Pclass  \
# 35            36         0       1
# 62            63         0       1
# 92            93         0       1
# 110          111         0       1
# 149          150         0       2
# 187          188         1       1
# 217          218         0       2
# 236          237         0       2
# 245          246         0       1
# 288          289         1       2
# 314          315         0       2
# 331          332         0       1
# 339          340         0       1
# 397          398         0       2
# 453          454         1       1
# 460          461         1       1
# 462          463         0       1
# 463          464         0       2
# 515          516         0       1
# 536          537         0       1
# 586          587         0       2
# 599          600         1       1
# 621          622         1       1
# 645          646         1       1
# 662          663         0       1
# ...

# %% [markdown]
# ## Create a new dataframe(df_kpi) that calculate the following KPIs by grouping (Pclass, age_group and economy_group) from the above df_survived dataframe
# #### 1. total records count
# #### 2. total survivors count
# #### 3. avg fare
# #### 4. maximum fare
# #### 5. minimum fare
# #### 6. total fare

# %%
#df_survived['Survived']=
df_kpi=df_survived.groupby(['Pclass','Age_Group','Economy_Group']).agg({'Survived':lambda x:x.eq(1).sum(),
                                                                   'Fare':['max','min','mean','sum']})

df_kpi.reset_index()
# Out:
#   Pclass Age_Group Economy_Group Survived      Fare                      \
#                                  <lambda>       max      min       mean
# 0      1     young          Rich        8  110.8833  25.5875  53.528376
# 1      2     young      Not Rich        1   27.0000  13.0000  19.906250
#
#
#          sum
# 0  1124.0959
# 1   159.2500

# %% [markdown]
# ## Merge df_survived and df_kpi on Pclass , age_group and economy_group columns

# %%
mergedata=pd.merge(df_survived,df_kpi,on=['Pclass','Age_Group','Economy_Group'])
mergedata
# Out:
# C:\Users\GAURAV~1\AppData\Local\Temp/ipykernel_14256/3922757007.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   mergedata=pd.merge(df_survived,df_kpi,on=['Pclass','Age_Group','Economy_Group'])
#     PassengerId  Survived  Pclass  \
# 0            36         0       1
# 1            63         0       1
# 2            93         0       1
# 3           111         0       1
# 4           188         1       1
# 5           246         0       1
# 6           332         0       1
# 7           340         0       1
# 8           454         1       1
# 9           461         1       1
# 10          463         0       1
# 11          516         0       1
# 12          537         0       1
# 13          600         1       1
# 14          622         1       1
# 15          646         1       1
# 16          663         0       1
# 17          699         0       1
# ...

# %% [markdown]
# ## Create a sales order data frame for first 6 months (Jan’21 to June’21) with dummy date with one record per date.
# #### Structure of data frame is below with sample data
#
# |OrderID|order_date|order_amount|
# |---|---|---|
# |1|01-01-2021|100|
# |2 |02-01- 2021|50|
# |...|...|...|
# |..|30-06-2021| 600|

# %%
sales=pd.DataFrame({
    'OrderId':[1,2,3,4,5,6],
    'Order_Date':['2022-01-03','2022-01-08','2022-01-11','2022-02-01','2022-05-01','2022-06-01'],
    'Order_Amount':[100,50,60,22,700,600]
})
sales
# Out:
#    OrderId  Order_Date  Order_Amount
# 0        1  2022-01-03           100
# 1        2  2022-01-08            50
# 2        3  2022-01-11            60
# 3        4  2022-02-01            22
# 4        5  2022-05-01           700
# 5        6  2022-06-01           600

# %% [markdown]
# ## Using above data frame create another data frame which gives you sales on weekdays and weekends for each of the 6 months (Jan’21 to June’21).
# #### Below is the schema for the dataframe.
#
# |Month |weekday_total_orderamount|weekend_total_order_amount|
# |---|---|---|
# |Jan| 100| 200|
# |Feb| 300| 400|

# %%
 
sales.Order_Date=pd.to_datetime(sales.Order_Date)
sales.loc[0,'Order_Date'].day_name()
sales['Day']=sales['Order_Date'].dt.day_name()
# sales1=pd.DataFrame(['Month','Weekday_total','WeekEnd_Total'])
# sales1['Month']=sales['Order_Date'].apply(lambda x:x.month_name())
# sales1['Weekday_total']=sales['Order_Date'].apply(new_row)
sales['Month']=sales['Order_Date'].dt.month_name()
sales['Weekday']=sales['Order_Date'].dt.weekday
sales['check']=sales['Weekday'].apply(lambda x:x<5)
sales['check']=sales['check'].map({False:'WeekEnd',True:'WeekDay'})
sales1=sales.groupby(['Month','check']).agg({'Order_Amount':'sum'})
#sales12=pd.DataFrame(sales1)
#sales12=sales1.pivot
#Month,check,Order_Amount
sales12=sales1.pivot_table('Order_Amount', ['Month'], 'check')
sales12.fillna(0)
# Out:
# check     WeekDay  WeekEnd
# Month
# February     22.0      0.0
# January     160.0     50.0
# June        600.0      0.0
# May           0.0    700.0

# %% [markdown]
# # Sql Questions

# %% [markdown]
# Considering the below transactions table
#
# |id|transaction_codetype|mcc_code|amount|
# |---|---|---|---|
# |1|ADS|0|-0.2|
# |2|ADOF|0|-2|
# |3|ADM|0|-25|
# |4|ADZ|0|-28|
# |5|W|0|-1|
# |6|FE0020|0|-0.8|
# |7|AD1|0|-20|
# |8|ADF1|0|-1|
# |9|A|4089|25|

# %% [markdown]
# #### Write sql query for selecting aggregated transfer amount  i.e, amount < 0.0 . Transaction code(ADS, ADOF, ADM) indicate that a transfer  happened.

# %%
select * from table_name where transaction_codetype='ADS' or  transaction_codetype='ADOF' or  transaction_codetype='ADM'

# %% [markdown]
# #### Write sql query for selecting aggregated deposits. ,i.e, amount > 0.0

# %%
select * from table_name where amount>0.0
